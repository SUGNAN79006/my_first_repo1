# %% [markdown]
# Hardware:
# Hardware is the physical parts of a computer that you can touch.
# Software:
# Software is the programs or instructions that tell the hardware what to do.
# Example
# Hardware Example: Keyboard ⌨
# Software Example: Microsoft Word
